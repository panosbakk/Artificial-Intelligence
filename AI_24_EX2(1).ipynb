# %% [markdown]
# ##### ❗Προσοχή: Συμπληρώστε τα ονόματα των μελών της ομάδας σας
#
#      Ονοματεπώνυμο 1ου μέλους: Μπακαλούδης Παναγιώτης
#              email 1ου μέλους: el19600@mail.ntua.gr
#
#      Ονοματεπώνυμο 2ου μέλους: Απόστολος Κυριακόπουλος
#              email 2ου μέλους: el20842@mail.ntua.gr

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Ενότητα 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /content/drive

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository -y ppa:swi-prolog/devel
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install 'git+https://github.com/yuce/pyswip@master#egg=pyswip'

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
path = '/content/drive/MyDrive/AI_24/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv(path + "movies_metadata.csv")
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  text = text.lstrip('\n')
  text = text.lstrip('"')
  text = text.rstrip('\n')
  text = text.rstrip(';')
  text = text.rstrip('"')
  text = text.replace('""', '"')
  text = text.replace(';"', '')
  text = text.replace('";', '')
  text = text.replace('&amp"', '&')
  text = text.replace('"', '')
  return text

# %%
from pyswip import Prolog

## create World
## Ορίζουμε τον κόσμο μας
prolog = Prolog()

# %%
## Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
## αρχικά σε μια λίστα με το όνομα literals
literals = []
for row in data.itertuples(index = True, name = 'Pandas'):
    movieTitle = clean_text(getattr(row, 'movie_title'))

    ## print(list(eval(getattr(row, 'production_companies'))))

    for genre in getattr(row, 'genres').split("|"):
        literals.append(f"genre('{movieTitle}','{genre}')")

    for plotKeyword in getattr(row, 'plot_keywords').split("|"):
        plotKeyword = plotKeyword.replace("'", '')
        literals.append(f"plot_keyword('{movieTitle}','{plotKeyword}')")

    literals.append(f"language('{movieTitle}','{getattr(row, 'language')}')")

    for productionCompany in list(eval(getattr(row, 'production_companies'))):
        pcname = productionCompany["name"].replace("'", "")
        literals.append(f"production_company('{movieTitle}','{pcname}')")

    ## some names include apostrophes, others include nicknames in double quotes
    name = clean_text(getattr(row, 'director_name'))
    literals.append(f"director('{movieTitle}','{name}')")

    name = clean_text(getattr(row, 'actor_1_name'))
    literals.append(f"actor('{movieTitle}','{name}')")

    name = clean_text(getattr(row, 'actor_2_name'))
    literals.append(f"actor('{movieTitle}','{name}')")

    name = clean_text(getattr(row, 'actor_3_name'))
    literals.append(f"actor('{movieTitle}','{name}')")

    if(getattr(row, 'title_year') != "UNK"):
        year = int(getattr(row, 'title_year'))
        decade = str(year - year % 10)
        literals.append(f"decade('{movieTitle}','{decade}')")

## Η Prolog θέλει τα κατηγορήματά της με την σειρά
literals.sort()
with open("literals.txt", 'w', encoding = "utf-8") as f:
    for l in literals: f.write(l + '\n')

for literal in literals:
    prolog.assertz(literal)

# %% [markdown]
# Η παραπάνω μέθοδος διαβάζει τα αρχικά δεδομένα, και κατασκευάζει και αποθηκεύει όλα τα κατηγορήματα της μορφής director(movieName, directorName) κτλ στο αρχείο literals.txt, ούτως ώστε σε επόμενες εκτελέσεις του notebook να διαβάζουμε τα χρήσιμα δεδομένα απ' ευθείας από εκεί.

# %%
## FOR SUBSEQUENT EXECUTIONS
with open("/content/literals.txt", 'r', encoding = "utf-8") as f:
    for line in f: prolog.assertz(line.strip())

# %%
## Κάνουμε consult ένα έτοιμο αρχείο στον κόσμο που περιέχει τα ζητούμενα κατηγορήματα
prolog.consult("/content/drive/My Drive/AI_24/db.pl")

# %%
q = prolog.query("sameDirector('Iron Man', M)")
for sol in q: print(sol)
q.close()
# Out:
# {'M': 'Elf'}
# {'M': 'Iron Man 2'}
# {'M': 'Made'}
# {'M': 'The Jungle Book'}
# {'M': 'Zathura: A Space Adventure'}

# %%
q = prolog.query("atLeastOneCommonActor('Iron Man 2', M)")
for sol in q: print(sol)
q.close()
# Out:
# {'M': 'Brooklyns Finest'}
# {'M': 'Crash'}
# {'M': 'Flight'}
# {'M': 'Hotel for Dogs'}
# {'M': 'Iron Man 3'}
# {'M': 'Mission to Mars'}
# {'M': 'Out of Sight'}
# {'M': 'Reign Over Me'}
# {'M': 'Swordfish'}
# {'M': 'The Family Man'}
# {'M': 'The Guard'}
# {'M': 'Volcano'}
# {'M': 'Contagion'}
# {'M': 'Glee: The Concert Movie'}
# {'M': 'Infamous'}
# {'M': 'Iron Man 3'}
# {'M': 'Jefferson in Paris'}
# {'M': 'Mortdecai'}
# {'M': 'Se7en'}
# {'M': 'Shakespeare in Love'}
# {'M': 'Sky Captain and the World of Tomorrow'}
# {'M': 'The Good Night'}
# {'M': 'The Pallbearer'}
# {'M': 'The Royal Tenenbaums'}
# {'M': 'The Talented Mr. Ripley'}
# {'M': 'Two Lovers'}
# {'M': 'Captain America: Civil War'}
# {'M': 'Captain America: The Winter Soldier'}
# {'M': 'Don Jon'}
# {'M': 'Eight Legged Freaks'}
# {'M': 'Ghost World'}
# {'M': 'Her'}
# {'M': 'In Good Company'}
# {'M': 'Lost in Translation'}
# {'M': 'Match Point'}
# {'M': 'The Black Dahlia'}
# {'M': 'The Horse Whisperer'}
# {'M': 'The Island'}
# {'M': 'The Other Boleyn Girl'}
# {'M': 'The Prestige'}
# {'M': 'The Spirit'}
# {'M': 'We Bought a Zoo'}

# %%
q = prolog.query("atLeastThreeCommonGenres('Iron Man', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Pacific Rim', 'Star Wars: Clone Wars: Volume 1', 'G.I. Joe: The Rise of Cobra', 'Beastmaster 2: Through the Portal of Time', 'The Day After Tomorrow', 'The Hunger Games: Catching Fire', 'Timeline', 'Man of Steel', 'Superman IV: The Quest for Peace', 'X-Men: Days of Future Past', 'Predators', 'Mad Max Beyond Thunderdome', 'Oblivion', 'Race to Witch Mountain', 'The Wolverine', 'Star Trek III: The Search for Spock', 'Transformers: Age of Extinction', 'Independence Day: Resurgence', 'The Black Hole', 'The Fifth Element', 'The Matrix Revolutions', 'Anacondas: The Hunt for the Blood Orchid', 'Captain America: The Winter Soldier', 'Teenage Mutant Ninja Turtles', 'G.I. Joe: Retaliation', 'AVP: Alien vs. Predator', 'Avengers: Age of Ultron', 'Dune', 'Escape from L.A.', 'Terminator Genisys', 'Independence Day', 'Dragonball Evolution', 'Fantastic Four', 'Spy Kids 3-D: Game Over', 'Star Trek: Generations', 'The Blood of Heroes', 'Jimmy Neutron: Boy Genius', 'Star Trek V: The Final Frontier', 'Jupiter Ascending', 'The Time Machine', 'Godzilla 2000', 'The Island', 'The Covenant', 'Underworld: Rise of the Lycans', 'I Am Number Four', 'Superman Returns', 'Mad Max 2: The Road Warrior', 'Spawn', 'Superman', 'Starship Troopers', 'The Empire Strikes Back', 'Star Wars: Episode II - Attack of the Clones', 'Mystery Men', 'Deep Rising', 'Street Fighter: The Legend of Chun-Li', 'The Shadow', 'Men in Black II', 'TRON: Legacy', 'Resident Evil: Afterlife', 'Superman III', 'Teenage Mutant Ninja Turtles III', 'Six-String Samurai', 'Transformers', 'Jurassic World', 'Serenity', 'Steel', 'Total Recall', 'X2', 'Shin Godzilla', 'Captain America: Civil War', 'Divergent', 'Sky Captain and the World of Tomorrow', '9', 'Men in Black', 'Paycheck', 'Star Trek', 'The Core', 'Small Soldiers', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'The Matrix Reloaded', 'Moonraker', 'Superman II', 'Congo', 'Star Trek Into Darkness', 'X-Men: First Class', 'X-Men', 'Suicide Squad', 'X-Men Origins: Wolverine', 'U.F.O.', 'The Saint', 'Captain America: The First Avenger', 'Green Lantern', 'Knowing', 'Return of the Jedi', 'Journey to the Center of the Earth', 'Babylon A.D.', 'Firefox', 'Jurassic Park III', 'Megaforce', 'Damnation Alley', 'Planet of the Apes', 'Blade: Trinity', 'The Avengers', 'The Lovers', 'The Host', 'Star Wars', 'Ant-Man', 'The Lost World: Jurassic Park', 'Inception', 'Star Trek VI: The Undiscovered Country', '2012', 'Enders Game', 'Journey to Saturn', 'Guardians of the Galaxy', 'Titan A.E.', 'Star Trek Beyond', 'Southland Tales', 'Avatar', 'Mad Max', 'A Sound of Thunder', 'Star Trek II: The Wrath of Khan', 'Star Trek: Nemesis', 'Predator', 'RoboCop 3', 'Armageddon', 'After Earth', 'Wild Wild West', 'Iron Man 2', 'Logans Run', 'Battleship', 'Star Wars: Episode I - The Phantom Menace', 'Transformers: Dark of the Moon', 'The Hunger Games: Mockingjay - Part 2', 'Iron Man 3', 'Mad Max: Fury Road', 'Journey 2: The Mysterious Island', 'X-Men: The Last Stand', 'Star Trek: First Contact', 'Thunderbirds', 'The Abyss', 'Transformers: Revenge of the Fallen', 'John Carter', 'Star Trek: Insurrection', 'The Incredible Hulk', 'Batman', 'Star Wars: Episode III - Revenge of the Sith', 'Final Fantasy: The Spirits Within', 'Sheena'}

# %%
q = prolog.query("sameDirector('Home Alone', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Rent', 'Stepmom', 'Home Alone 2: Lost in New York', 'Percy Jackson & the Olympians: The Lightning Thief', 'Pixels', 'Harry Potter and the Philosophers Stone', 'Harry Potter and the Chamber of Secrets', 'Mrs. Doubtfire', 'Bicentennial Man', 'I Love You, Beth Cooper'}

# %%
q = prolog.query("atLeastTwoCommonActors('Home Alone', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Home Alone 2: Lost in New York'}

# %% [markdown]
# Στο αρχείο db.pl έχουν συμπεριληφθεί τα κατηγορήματα για όλα τα ζητούμενα του πρώτου μέρους (οριμένα ενδεικτικά παραπάνω), όπως και τα κατηγορήματα find_sim για το σύστημα συστάσεων. Να σημειωθεί ότι, παρ' όλο που έχουμε γράψει 9 κατηγορήματα find_sim, κλιμακούμενης εξειδίκευσης, για την υλοποίηση της μεθόδου simpleRecommender, στην οποία βασίζονται τα μέρη 2 και 3, έχουν χρησιμοποιηθεί μόνο τα 1 έως και 4. Αυτό επειδή η βιβλιοθήκη pyswip δεν διαχειρίζεται ικανοποιητικά μεγάλο όγκο δεδομένων και κατηγορημάτων, με αποτέλεσμα, όταν προσπαθούμε να τρέξουμε όλα τα κατηγορήματα σε μη ευτελές ποσοστό των δεδομένων εκπαίδευσης, η ροή του notebook να διακόπτεται με σφάλμα (crash).

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
def simple_recommender(movie):
    s = set()
    for i in range(1, 5):
        q = prolog.query("find_sim_" + str(i) + "('" + movie +"', M)")
        for sol in q:
            m = sol['M']
            s.add(sol['M'])
        q.close()
    return s

# %%
list(simple_recommender('Avatar'))
# Out:
# ['Lucky Numbers',
#  'The Death and Life of Bobby Z',
#  'The Quiet American',
#  'The Sisterhood of the Traveling Pants 2',
#  'Mars Attacks!',
#  'Warriors of Virtue',
#  'Noah',
#  'All The Queens Men',
#  'London Has Fallen',
#  'Rush Hour 3',
#  'Penguins of Madagascar',
#  'The Forbidden Kingdom',
#  'The Borrowers',
#  'Twilight Zone: The Movie',
#  'Green Street Hooligans: Underground',
#  'White Fang',
#  'Born Of War',
#  'Love Me Tender',
#  'The Iron Giant',
#  'The Jacket',
#  'The Four Feathers',
#  'Krull',
#  'Alvin and the Chipmunks',
#  'The Dark Knight',
#  'Navy Seals vs. Zombies',
#  'The Hobbit: An Unexpected Journey',
#  'Underclassman',
#  'D-Tox',
#  'Taken',
#  'The Hobbit: The Desolation of Smaug',
#  'Harper',
#  'Around the World in 80 Days',
#  'Heist',
#  'Resident Evil: Extinction',
#  'Scott Pilgrim vs. the World',
#  'G.I. Jane',
#  'Open Season',
#  'Inglourious Basterds',
#  'The Bourne Identity',
#  'Sahara',
#  'Spider-Man 2',
#  'Lone Wolf McQuade',
#  '30 Minutes or Less',
#  'The Brave Little Toaster',
#  'Blackthorn',
#  'Green Zone',
#  'Alien: Resurrection',
#  'Evan Almighty',
#  'The Hunt for Red October',
#  'Æon Flux',
#  'Grabbers',
#  'The Matrix Reloaded',
#  'Moonraker',
#  'Ghost Town',
#  'Dragon Nest: Warriors Dawn',
#  'Area 51',
#  'Scooby-Doo',
#  'Suicide Squad',
#  'Eight Below',
#  'Solaris',
#  'The Prophecy',
#  'Beasts of the Southern Wild',
#  'Babylon A.D.',
#  'The Expendables',
#  'The Proposition',
#  'Pootie Tang',
#  'The Tempest',
#  'Night at the Museum',
#  'Blade: Trinity',
#  'Holes',
#  'Queen of the Mountains',
#  'War',
#  'Machete Kills',
#  'Just Visiting',
#  'Sphinx',
#  'The Triplets of Belleville',
#  'Hardflip',
#  'Smillas Sense of Snow',
#  'Batman: The Dark Knight Returns, Part 2',
#  'Robin and Marian',
#  'Airlift',
#  'Highlander: The Final Dimension',
#  'Valiant',
#  'Waterworld',
#  'Circle',
#  'The Great Escape',
#  'Iron Man 2',
#  'Star Wars: Episode I - The Phantom Menace',
#  'Bedazzled',
#  'Kiss of the Dragon',
#  'The Monkey King 2',
#  'A Monster in Paris',
#  'Sunshine',
#  'Quest for Fire',
#  'The Boys from Brazil',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Next Day Air',
#  'Star Trek: First Contact',
#  'Ong Bak 2',
#  'Dogma',
#  'Casper',
#  'The Brain That Wouldnt Die',
#  'Gladiator',
#  'The Ice Pirates',
#  'The Wizard of Oz',
#  'Money Train',
#  'Star Wars: Clone Wars: Volume 1',
#  'Pacific Rim',
#  'Into the Wild',
#  'Extreme Ops',
#  'The Man from U.N.C.L.E.',
#  'Babys Day Out',
#  'The Grandmaster',
#  'The Cold Light of Day',
#  'Highlander: Endgame',
#  'Yogi Bear',
#  'Legends of the Fall',
#  'Under the Skin',
#  'Dark Shadows',
#  'Killer Elite',
#  'Three Kingdoms: Resurrection of the Dragon',
#  'Stolen',
#  'Sky High',
#  'Melancholia',
#  'The Land Before Time',
#  'Queen of the Damned',
#  'The Matrix Revolutions',
#  'Sherlock Holmes: A Game of Shadows',
#  'Ted',
#  'Grindhouse',
#  'Enchanted',
#  'The Faculty',
#  'Charlottes Web',
#  'The Score',
#  'The Country Bears',
#  'Cirque du Freak: The Vampires Assistant',
#  'Joe Dirt',
#  'The Last Witch Hunter',
#  'Jason X',
#  'Rubber',
#  'Meet Dave',
#  'The Legend of Drunken Master',
#  'Tuck Everlasting',
#  'Space Battleship Yamato',
#  'The Bounty Hunter',
#  'The Invasion',
#  'Stealing Harvard',
#  'City of Ember',
#  'Atlas Shrugged Part III: Who is John Galt?',
#  'I Am Legend',
#  'Anaconda',
#  'Race',
#  'The NeverEnding Story',
#  'H.',
#  'The Replacement Killers',
#  'E.T. the Extra-Terrestrial',
#  'Swelter',
#  'Tank Girl',
#  'Jurassic World',
#  'xXx: State of the Union',
#  'Fools Gold',
#  'The Adventures of Ford Fairlane',
#  'Total Recall',
#  'Austin Powers in Goldmember',
#  'Conspiracy Theory',
#  'The Last Stand',
#  'The Flintstones in Viva Rock Vegas',
#  'Scooby-Doo 2: Monsters Unleashed',
#  'Edward Scissorhands',
#  'Red State',
#  'Star Trek',
#  'Small Soldiers',
#  'Kung Fu Panda 3',
#  'The Good, The Bad, The Weird',
#  'Letters from Iwo Jima',
#  'Little Nicky',
#  'Blade II',
#  'The Green Mile',
#  'Alex Cross',
#  'Daybreakers',
#  'Beverly Hills Chihuahua',
#  'Force 10 from Navarone',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'The Losers',
#  'Knowing',
#  'Young Guns',
#  'Stripes',
#  'Never Let Me Go',
#  'The Other Guys',
#  'Hudson Hawk',
#  'Small Time Crooks',
#  'The Legend of Bagger Vance',
#  'Megaforce',
#  'Ronin',
#  'Diamonds Are Forever',
#  'Invasion U.S.A.',
#  'Southpaw',
#  'Antz',
#  'One for the Money',
#  'Mr. Peabody & Sherman',
#  '21 Jump Street',
#  'The Glimmer Man',
#  'Time Bandits',
#  'The Host',
#  'Austin Powers: International Man of Mystery',
#  'Steamboy',
#  'Hanna',
#  'St. Trinians',
#  'Return to Oz',
#  'Lara Croft: Tomb Raider',
#  'Nutty Professor II: The Klumps',
#  'Its a Mad, Mad, Mad, Mad World',
#  'Night at the Museum: Secret of the Tomb',
#  'Love & Basketball',
#  'Armageddon',
#  'Skyline',
#  'Return to Never Land',
#  'Kate & Leopold',
#  'Cargo',
#  'Vanilla Sky',
#  'RED 2',
#  'Willy Wonka & the Chocolate Factory',
#  'The Andromeda Strain',
#  'Nighthawks',
#  'The Man with the Golden Gun',
#  'Hulk',
#  'The Bourne Supremacy',
#  'War, Inc.',
#  'Walking Tall',
#  'Rabbit-Proof Fence',
#  'The Adventures of Sharkboy and Lavagirl',
#  'Cliffhanger',
#  'Made',
#  'Jaws',
#  'Conan the Destroyer',
#  'Death Becomes Her',
#  'The Jungle Book 2',
#  'A Man Apart',
#  'Air Force One',
#  '12 Rounds',
#  'Scarface',
#  'Cast Away',
#  '300: Rise of an Empire',
#  'The Walking Deceased',
#  'Ip Man 3',
#  'Moon',
#  'Unstoppable',
#  'Black November',
#  'The Wolverine',
#  'The Big Hit',
#  'Sphere',
#  'Travellers and Magicians',
#  'Shrek 2',
#  'Megiddo: The Omega Code 2',
#  'The Croods',
#  'Antarctica: A Year on Ice',
#  'The Sweeney',
#  'Fantastic Four',
#  'Patriot Games',
#  'Bee Movie',
#  'Rampage',
#  'Colombiana',
#  'The Hunger Games',
#  'The Transporter Refueled',
#  'The Tree of Life',
#  'Inkheart',
#  'The Warlords',
#  'The Finest Hours',
#  'Robots',
#  'The Ghastly Love of Johnny X',
#  'Roar',
#  'Ballistic: Ecks vs. Sever',
#  'A Good Day to Die Hard',
#  'Repo! The Genetic Opera',
#  'The Bodyguard',
#  'High Heels and Low Lifes',
#  'Goldfinger',
#  'Six-String Samurai',
#  'U-571',
#  'Rush',
#  'Creepshow',
#  'Treasure Planet',
#  'Like Mike',
#  'Shipwrecked',
#  'An American Carol',
#  'Doom',
#  'Men in Black',
#  'Prince of Persia: The Sands of Time',
#  'Dantes Peak',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'Batman & Robin',
#  'The Last of the Mohicans',
#  'Behind Enemy Lines',
#  'Super',
#  'Get Carter',
#  'The Brass Teapot',
#  'Hot Tub Time Machine',
#  'K-PAX',
#  'The Indian in the Cupboard',
#  'Alice Through the Looking Glass',
#  'The Time Travelers Wife',
#  'Damnation Alley',
#  'The Sorcerers Apprentice',
#  '3 Strikes',
#  'Blindness',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Surrogates',
#  'Wind Walkers',
#  'Indiana Jones and the Last Crusade',
#  'The Huntsman: Winters War',
#  'Capricorn One',
#  '28 Weeks Later',
#  'Lions for Lambs',
#  'Alien³',
#  'Daylight',
#  'The Dukes of Hazzard',
#  'The Worlds End',
#  'A Perfect Getaway',
#  'Harry Potter and the Philosophers Stone',
#  'Kung Fu Panda',
#  '10 Cloverfield Lane',
#  'Saints and Soldiers',
#  'Big Miracle',
#  'The Devils Tomb',
#  'Somewhere in Time',
#  'Logans Run',
#  'Tora! Tora! Tora!',
#  'Jekyll and Hyde ... Together Again',
#  'Prometheus',
#  'Paint Your Wagon',
#  'Con Air',
#  'Crocodile Dundee II',
#  'The Last Samurai',
#  'Training Day',
#  'Cat People',
#  'Battle: Los Angeles',
#  'Grand Theft Parsons',
#  'Pandorum',
#  'The Raid',
#  'Supercross',
#  'Shaft',
#  'The Odd Life of Timothy Green',
#  'Automata',
#  'Dawn of the Planet of the Apes',
#  'Contact',
#  'Elektra',
#  'Howls Moving Castle',
#  'No Escape',
#  'The Mummy Returns',
#  'Muppets Most Wanted',
#  'Abraham Lincoln: Vampire Hunter',
#  'Kiss of Death',
#  'X-Men: Apocalypse',
#  'Independence Day: Resurgence',
#  'Vantage Point',
#  'The Brothers Grimm',
#  'Unleashed',
#  'Sausage Party',
#  'Malone',
#  'Nanny McPhee and the Big Bang',
#  '2001: A Space Odyssey',
#  'Deep Impact',
#  'Jason Goes to Hell: The Final Friday',
#  'Snakes on a Plane',
#  'The Last Legion',
#  'Hells Angels',
#  'Hot Rod',
#  'Brave',
#  'Machine Gun Preacher',
#  'The Descent',
#  'Safety Not Guaranteed',
#  'Primer',
#  'Are We There Yet?',
#  'The Jungle Book',
#  'Pound of Flesh',
#  'Checkmate',
#  'House of Flying Daggers',
#  'Commando',
#  'Back to the Future Part II',
#  'Star Trek: The Motion Picture',
#  'Bubba Ho-tep',
#  'Howard the Duck',
#  'Frequency',
#  'Along Came a Spider',
#  'Starship Troopers',
#  'Spaced Invaders',
#  'Hidalgo',
#  'Flatliners',
#  'Jade',
#  'Never Back Down',
#  'Agent Cody Banks',
#  'TRON: Legacy',
#  'Allegiant',
#  'Half Past Dead',
#  'Creative Control',
#  'Nancy Drew',
#  'The Smurfs 2',
#  'Flash Gordon',
#  'S.W.A.T.',
#  'Proof of Life',
#  '9',
#  'Paycheck',
#  'The Adventures of Rocky & Bullwinkle',
#  'The Green Hornet',
#  'The Kingdom',
#  'Across the Universe',
#  'Clash of the Titans',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'Epic Movie',
#  'Airborne',
#  'Midnight Special',
#  'Babe: Pig in the City',
#  'Gremlins',
#  'WarGames',
#  'Reno 911!: Miami',
#  'Into the Blue',
#  'Planet of the Apes',
#  'The Fugitive',
#  'Ninja Assassin',
#  'Harold & Kumar Go to White Castle',
#  'Madison',
#  'DOA: Dead or Alive',
#  'Thunder and the House of Magic',
#  'The Adventures of Huck Finn',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Journey to Saturn',
#  'Menace II Society',
#  'Assassins',
#  'Homefront',
#  'The Thief and the Cobbler',
#  'The Misfits',
#  'Red Sky',
#  'Curious George',
#  'The First Great Train Robbery',
#  'Punisher: War Zone',
#  'Live and Let Die',
#  'Drive Hard',
#  'Escape from New York',
#  'The Lord of the Rings: The Return of the King',
#  'You Only Live Twice',
#  'The Green Inferno',
#  'The Beach',
#  'Scrooged',
#  'The Muppet Christmas Carol',
#  'A Low Down Dirty Shame',
#  'Terminator 3: Rise of the Machines',
#  'Rescue Dawn',
#  'C.H.U.D.',
#  'The Smurfs',
#  'The Man',
#  'Khumba',
#  'King Kong',
#  'The Gunman',
#  'Click',
#  'Blade',
#  'Rockaway',
#  'The Last Dragon',
#  'The Chronicles of Riddick',
#  'The Day the Earth Stood Still',
#  'Rise of the Planet of the Apes',
#  'Stake Land',
#  'Rio',
#  'Thor: The Dark World',
#  'The Rock',
#  'Out of Inferno',
#  'Nebraska',
#  'The Lost Skeleton of Cadavra',
#  'Transformers: Revenge of the Fallen',
#  'Star Trek: Insurrection',
#  'Meteor',
#  'Aliens in the Attic',
#  'Bronson',
#  'The Ballad of Cable Hogue',
#  'Black Hawk Down',
#  'Pocahontas',
#  'Operation Chromite',
#  'In Too Deep',
#  'Nicholas Nickleby',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Mad Max Beyond Thunderdome',
#  'The League of Extraordinary Gentlemen',
#  'The Way of the Gun',
#  'The Adjustment Bureau',
#  'Young Sherlock Holmes',
#  'A.I. Artificial Intelligence',
#  'Snow White: A Tale of Terror',
#  'Cloud Atlas',
#  'Paul Blart: Mall Cop',
#  'Run All Night',
#  'Avengers: Age of Ultron',
#  'Independence Day',
#  'Spy Kids 3-D: Game Over',
#  'The True Story of Puss n Boots',
#  'Blood Diamond',
#  '55 Days at Peking',
#  'The Book of Life',
#  'Mary Poppins',
#  'Ghost',
#  'The Purge: Election Year',
#  'Beowulf',
#  'Sweet Sweetbacks Baadasssss Song',
#  'Code of Honor',
#  'The Twilight Saga: New Moon',
#  'The Newton Boys',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Maleficent',
#  'Wristcutters: A Love Story',
#  'Die Hard 2',
#  'Skyfall',
#  'Red Cliff',
#  'The Lion of Judah',
#  'Shinjuku Incident',
#  'Dick Tracy',
#  'The Twilight Saga: Eclipse',
#  'Paparazzi',
#  'Waterloo',
#  'Bill & Teds Excellent Adventure',
#  'Sliding Doors',
#  'Spirit: Stallion of the Cimarron',
#  'Ghosts of Mars',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'District B13',
#  'Eagle Eye',
#  'The Addams Family',
#  'The 6th Day',
#  'Deuces Wild',
#  'Hancock',
#  'The Saint',
#  'Centurion',
#  'Maze Runner: The Scorch Trials',
#  'Return of the Jedi',
#  'Fear and Loathing in Las Vegas',
#  'Shanghai Knights',
#  'Edge of Tomorrow',
#  'The Lego Movie',
#  'Compadres',
#  'Bill & Teds Bogus Journey',
#  'Taken 2',
#  'Walking With Dinosaurs',
#  'Trash',
#  'Dreamcatcher',
#  'Undisputed',
#  'Khiladi 786',
#  'Titan A.E.',
#  'Cloverfield',
#  'Falcon Rising',
#  'Donnie Darko',
#  'The Protector',
#  'True Romance',
#  'Incident at Loch Ness',
#  'World War Z',
#  'The Promise',
#  'Sabotage',
#  'Ultramarines: A Warhammer 40,000 Movie',
#  'The Imaginarium of Doctor Parnassus',
#  'The Secret Life of Walter Mitty',
#  'Fast Five',
#  'Cube',
#  'District 9',
#  'Groundhog Day',
#  'Kickboxer: Vengeance',
#  'Screwed',
#  'Transformers: Dark of the Moon',
#  'The Polar Express',
#  'Escape Plan',
#  'Taken 3',
#  'The Cat in the Hat',
#  'Tango & Cash',
#  'Raise the Titanic',
#  'American Ninja 2: The Confrontation',
#  'Beyond Borders',
#  'The Wash',
#  'Seeking a Friend for the End of the World',
#  'The Living Daylights',
#  'Man on Fire',
#  'Stone Cold',
#  'Children of Men',
#  'Fight to the Finish',
#  'The Matrix',
#  'The Walk',
#  'Shrek',
#  'VeggieTales: The Pirates Who Dont Do Anything',
#  'The Three Musketeers',
#  'Arthur and the Invisibles',
#  'A Lonely Place to Die',
#  'Donovans Reef',
#  'Jack Brooks: Monster Slayer',
#  'Predators',
#  'Haywire',
#  'The Book of Eli',
#  'Ghost Rider',
#  'RED',
#  'Dragon Wars: D-War',
#  'Looper',
#  'Poseidon',
#  'Stormbreaker',
#  'Driven',
#  'Men of War',
#  'Henry V',
#  'G.I. Joe: Retaliation',
#  'Duma',
#  'The Maze Runner',
#  'The Prince of Egypt',
#  'Four Brothers',
#  'Signs',
#  'Wasabi',
#  'Machine Gun McCain',
#  'Dragonball Evolution',
#  'The Mask of Zorro',
#  'The Blood of Heroes',
#  'I Got the Hook Up',
#  'The Bounty',
#  'Harry Brown',
#  'The Hobbit: The Battle of the Five Armies',
#  'Black Rain',
#  'Sucker Punch',
#  'Contraband',
#  'About Time',
#  'The Scorpion King',
#  'Lucy',
#  'Hereafter',
#  'Pontypool',
#  'The Lawnmower Man',
#  'Mission: Impossible - Rogue Nation',
#  'Parker',
#  'The Spiderwick Chronicles',
#  'The Greatest Show on Earth',
#  'The Adventurer: The Curse of the Midas Box',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Ride Along 2',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Street Fighter: The Legend of Chun-Li',
#  'Changing Lanes',
#  'Shark Tale',
#  'Superman III',
#  'Land of the Lost',
#  'Wild Hogs',
#  '28 Days Later',
#  'Dawn of the Crescent Moon',
#  'Broken Arrow',
#  'Shooter',
#  'The Expendables 3',
#  'Invaders from Mars',
#  'Alien',
#  'Basic',
#  'The Mechanic',
#  'Underworld',
#  'The Helix... Loaded',
#  'The Spy Who Loved Me',
#  'Bruce Almighty',
#  'Taxman',
#  'Oldboy',
#  'The Hebrew Hammer',
#  'X-Men',
#  'Grosse Pointe Blank',
#  'The X Files: I Want to Believe',
#  'Blue Streak',
#  '300',
#  'Code Name: The Cleaner',
#  'Curse of the Golden Flower',
#  'Master and Commander: The Far Side of the World',
#  'Timecrimes',
#  'Home Alone 2: Lost in New York',
#  'The Last Castle',
#  'Reign of Assassins',
#  '22 Jump Street',
#  'The Postman',
#  'Snow Dogs',
#  'Shrek the Third',
#  'Deadpool',
#  'Terminator Salvation',
#  'Micmacs',
#  'The Chronicles of Narnia: Prince Caspian',
#  'Foodfight!',
#  'Battlefield Earth',
#  'Harley Davidson and the Marlboro Man',
#  'The Inhabited Island',
#  'See Spot Run',
#  'Conan the Barbarian',
#  'The French Connection',
#  'Decoys',
#  'V for Vendetta',
#  'Journey 2: The Mysterious Island',
#  'Quarantine',
#  'Sanctum',
#  'Never Say Never Again',
#  'Lethal Weapon 3',
#  'Silverado',
#  'Jaws: The Revenge',
#  'The Adventures of Pinocchio',
#  'Sorcerer',
#  'Space Jam',
#  'The Black Hole',
#  'Rapa Nui',
#  'RoboCop',
#  'Delgo',
#  'Escape from L.A.',
#  'The Spy Next Door',
#  'The Lord of the Rings: The Two Towers',
#  'Prophecy',
#  'Warlock: The Armageddon',
#  'Wolves',
#  'Star Trek: Generations',
#  'National Treasure',
#  'Planet 51',
#  'In the Heart of the Sea',
#  'Rumble in the Bronx',
#  'Enemy of the State',
#  'Harry Potter and the Goblet of Fire',
#  'Touching the Void',
#  'Spider-Man 3',
#  'The Great Raid',
#  'Without a Paddle',
#  'Queen Crab',
#  'Pineapple Express',
#  'Back to the Future Part III',
#  'Year One',
#  'Bait',
#  'Hero',
#  'Johnny English Reborn',
#  'Special',
#  '1941',
#  'The Pirates! In an Adventure with Scientists!',
#  'Snowpiercer',
#  'Crimson Tide',
#  'The One',
#  'The Shadow',
#  'Resident Evil: Afterlife',
#  'The Blues Brothers',
#  'The Count of Monte Cristo',
#  'Rob Roy',
#  'Epic',
#  'Mirror Mirror',
#  'Unsullied',
#  'Casino Royale',
#  'Riddick',
#  'Octopussy',
#  'Return to the Blue Lagoon',
#  'Divergent',
#  'The Mortal Instruments: City of Bones',
#  'Bridge to Terabithia',
#  'Flubber',
#  'Class of 1984',
#  'The Bourne Legacy',
#  'I Dreamed of Africa',
#  'Hocus Pocus',
#  'The Age of Adaline',
#  'Phantasm II',
#  'Resident Evil: Apocalypse',
#  'Dragon Blade',
#  'Once Upon a Time in Mexico',
#  'Penitentiary',
#  'Ransom',
#  'Goosebumps',
#  'Just Like Heaven',
#  'Green Lantern',
#  'Monte Carlo',
#  'Hit & Run',
#  'Warcraft',
#  'The Last Airbender',
#  'The Rundown',
#  'Clear and Present Danger',
#  'Outbreak',
#  'Soldier',
#  '3 Ninjas Kick Back',
#  'Silver Medalist',
#  'Whiteout',
#  'Princess Mononoke',
#  'From Paris with Love',
#  'Gone in Sixty Seconds',
#  'The Fourth Kind',
#  'Agora',
#  'The Legend of Hercules',
#  'The Family Man',
#  'Gun Shy',
#  'Star Trek VI: The Undiscovered Country',
#  '1911',
#  'Apocalypto',
#  'Ace Ventura: When Nature Calls',
#  'Speed',
#  'Hard to Be a God',
#  'Nomad: The Warrior',
#  'End of Days',
#  'Texas Rangers',
#  'Speed 2: Cruise Control',
#  'The Legend of the Lone Ranger',
#  'Days of Thunder',
#  'Arn: The Knight Templar',
#  'Battleship',
#  'The Train',
#  'The BFG',
#  'Rugrats in Paris: The Movie',
#  'Close Encounters of the Third Kind',
#  'Ishtar',
#  'Mars Needs Moms',
#  'The Beastmaster',
#  'Hollow Man',
#  'Mad Max: Fury Road',
#  'The Call of Cthulhu',
#  'A View to a Kill',
#  'Maximum Risk',
#  'The Interview',
#  'Blades of Glory',
#  'Witless Protection',
#  'The Musketeer',
#  'The Patriot',
#  'Money Talks',
#  'Heavy Metal',
#  'Abduction',
#  'Gamer',
#  'The Hunger Games: Catching Fire',
#  'Timeline',
#  'Seven Years in Tibet',
#  'Kingdom of Heaven',
#  'Race to Witch Mountain',
#  'Warrior',
#  'Star Trek III: The Search for Spock',
#  'Equilibrium',
#  'A Simple Wish',
#  'The Blue Butterfly',
#  'Jungle Shuffle',
#  'Laws of Attraction',
#  'Lost in Space',
#  'Re-Kill',
#  'Mercury Rising',
#  'The Dead Undead',
#  'Into the Grizzly Maze',
#  'Bulletproof Monk',
#  'Terminator Genisys',
#  'Baby Geniuses',
#  'Cypher',
#  '3 Days to Kill',
#  'In the Name of the King III',
#  'The Astronaut Farmer',
#  'Hellboy II: The Golden Army',
#  'Rango',
#  'The Siege',
#  'American Heist',
#  'Percy Jackson: Sea of Monsters',
#  'Batman Forever',
#  'Live Free or Die Hard',
#  'DragonHeart',
#  'Dredd',
#  'Dark Blue',
#  'Lucky Break',
#  'Point Break',
#  'Unnatural',
#  'Snow White and the Seven Dwarfs',
#  'Rise of the Guardians',
#  'Life of Pi',
#  'My Stepmother is an Alien',
#  'The Order',
#  'Transporter 2',
#  'X2',
#  'The Crocodile Hunter: Collision Course',
#  'Aladdin',
#  'Sky Captain and the World of Tomorrow',
#  'Die Another Day',
#  'White Squall',
#  'Aquamarine',
#  'The Negotiator',
#  'Gangsters Paradise: Jerusalema',
#  'Excessive Force',
#  'Megamind',
#  'The Monuments Men',
#  'Mission: Impossible - Ghost Protocol',
#  'Where the Wild Things Are',
#  'Set It Off',
#  'Never Back Down 2: The Beatdown',
#  'Journey to the Center of the Earth',
#  'The Pursuit of D.B. Cooper',
#  'Zombie Hunter',
#  'Contagion',
#  'A Passage to India',
#  'The Amazing Spider-Man',
#  'The Hunted',
#  'Northfork',
#  'Sleeper',
#  'Ready to Rumble',
#  'The Lovely Bones',
#  'Splash',
#  'Perrier’s Bounty',
#  'Kung Fu Jungle',
#  'White Noise 2: The Light',
#  'Eraserhead',
#  'Skin Trade',
#  'My Favorite Martian',
#  'Puss in Boots',
#  'The Hunger Games: Mockingjay - Part 2',
#  'In Her Line of Fire',
#  'You Dont Mess with the Zohan',
#  'The Spirit',
#  'Osmosis Jones',
#  'Cellular',
#  'Legend of the Guardians: The Owls of GaHoole',
#  'Superhero Movie',
#  'The Thirteenth Floor',
#  'The Legend of Tarzan',
#  'For Your Eyes Only',
#  'Fifty Dead Men Walking',
#  'John Carter',
#  'The Nutcracker: The Untold Story',
#  'Mutant World',
#  'Domino',
#  'Kill Bill: Vol. 1',
#  'The SpongeBob Movie: Sponge Out of Water',
#  'The Day After Tomorrow',
#  'The Man from Snowy River',
#  'Immortals',
#  'Savva. Heart of the Warrior',
#  'Herbie Fully Loaded',
#  'Idiocracy',
#  'White House Down',
#  'Beverly Hills Cop',
#  'Terminator 2: Judgment Day',
#  'Chicago Overcoat',
#  'Flight of the Intruder',
#  'The Santa Clause 2',
#  'Plastic',
#  'Bodyguards and Assassins',
#  'Dracula Untold',
#  'Seventh Son',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Pain & Gain',
#  'Seven Samurai',
#  'BloodRayne',
#  'Quigley Down Under',
#  'The Road',
#  'Diary of the Dead',
#  'Showdown in Little Tokyo',
#  'Atlas Shrugged Part II',
#  'Stargate: The Ark of Truth',
#  'The Specials',
#  'Thor',
#  'Spy Game',
#  'Spirited Away',
#  'Battle for the Planet of the Apes',
#  'Jimmy Neutron: Boy Genius',
#  'The Pink Panther',
#  'In Time',
#  'The Island',
#  'Digimon: The Movie',
#  'Pompeii',
#  'Spectre',
#  'Two Brothers',
#  'The Wicked Lady',
#  'Licence to Kill',
#  'Turbulence',
#  'Lawrence of Arabia',
#  'Kicks',
#  'Jack the Giant Slayer',
#  'The 51st State',
#  'Men in Black II',
#  'Charlie and the Chocolate Factory',
#  'Unknown',
#  'The Transporter',
#  'Gridiron Gang',
#  'Shrek Forever After',
#  'The Road to El Dorado',
#  'Charlies Angels: Full Throttle',
#  'The Mist',
#  'Wrath of the Titans',
#  'The Cave',
#  'Corpse Bride',
#  'Evil Dead II',
#  'All Hat',
#  'Night Watch',
#  'Undercover Brother',
#  'Alexander',
#  'The Man Who Knew Too Little',
#  'Act of Valor',
#  'Salvation Boulevard',
#  'The World Is Not Enough',
#  'Hugo',
#  'Drive',
#  'Monsters vs Aliens',
#  'Munich',
#  'Max Keebles Big Move',
#  'The Forsaken',
#  'Code 46',
#  'El Mariachi',
#  'Jason Bourne',
#  'The Quick and the Dead',
#  'Elysium',
#  'Furious 7',
#  'Star Wars',
#  'Charly',
#  'Central Intelligence',
#  'Inception',
#  'Righteous Kill',
#  'Cirque du Soleil: Worlds Away',
#  'The Brothers Bloom',
#  'Get Smart',
#  'Premium Rush',
#  'The Prince',
#  'Street Kings',
#  'Zoom',
#  'Cop Out',
#  'Crazy Stone',
#  'The Fast and the Furious: Tokyo Drift',
#  ...]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[0]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[0] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")
print(path)
# Out:
# /content/drive/MyDrive/AI_24/

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5091368264123065
# recall: 0.8111111111111111
# f1: 0.6229272063137518

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5103968079121585
# recall: 0.8694444444444442
# f1: 0.6329048344454946

# %%
metrics = []
for i in range (10):
    movieScore = train_recommender(train_ratings, rating_weights, score_weights, -1)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"average {metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# average precision: 0.510948905109489
# average recall: 0.9722222222222221
# average f1: 0.6698564593301434

# %% [markdown]
# Παρατηρούμε ότι αυξάνοντας το ποσοστό του train set που αξιοποιούμε, βελτιώνονται οι μετρικές ταξινόμησης. Σημαντικότερη βελτίωση παρατηρείται στο recall $(\frac{TP}{TP + FN})$, ενώ το precision $(\frac{TP}{TP + FP})$ σημειώνει ελάχιστη αύξηση. Αυτό σημαίνει ότι σταδιακά πετυχαίνουμε περισσότερες από τις ταινίες που ήθελε ο χρήστης, παράλληλα όμως αυξάνονται και οι μη σχετικές προτάσεις.
